# %% [markdown]
# # 訓練済みHifiGANモデルによる推論

# %%
import torch
from TTS.utils.audio import AudioProcessor
from TTS.vocoder.configs import HifiganConfig
from TTS.vocoder.models.gan import GAN

# %% [markdown]
# ## モデルのロード

# %%
config = HifiganConfig(
    batch_size=32,
    eval_batch_size=16,
    num_loader_workers=4,
    num_eval_loader_workers=4,
    run_eval=True,
    test_delay_epochs=5,
    epochs=1000,
    seq_len=8192,
    pad_short=2000,
    use_noise_augment=True,
    eval_split_size=10,
    print_step=25,
    print_eval=False,
    mixed_precision=False,
    lr_gen=1e-4,
    lr_disc=1e-4
)

# %%
# init audio processor
ap = AudioProcessor(**config.audio.to_dict())

# %%
device = torch.device("cuda:0")
model = GAN(config, ap).to(device)

# %%
checkpoint_path = "../recipes/ljspeech/hifigan/run-November-14-2022_09+43AM-b686c097/checkpoint_70000.pth"
model.load_checkpoint(config, checkpoint_path, eval=True)

# %% [markdown]
# ## ボコーダーの推論

# %%
import matplotlib.pyplot as plt
from IPython.display import display, Audio
# %matplotlib inline

# %%
wavpath = "../recipes/ljspeech/LJSpeech-1.1/wavs/LJ001-0001.wav"

# %%
audio = ap.load_wav(wavpath)
audio.shape

# %%
display(Audio(audio, rate=config.audio.sample_rate))

# %%
mel = ap.melspectrogram(audio)
mel = torch.from_numpy(mel)
mel = mel.unsqueeze(0).to(device)
mel.shape

# %%
recon_audio = model.inference(mel)
recon_audio = recon_audio.squeeze().cpu().numpy()
recon_audio.shape

# %%
plt.plot(recon_audio);

# %%
display(Audio(recon_audio, rate=config.audio.sample_rate))
